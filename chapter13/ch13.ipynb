# %%
import os
path = os.getcwd()

# %% [markdown]
# 13-1 数据探索

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
inputfile = path + '/data/data1.csv'
data1 = pd.read_csv(inputfile)
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 14 columns):
# x1     20 non-null int64
# x2     20 non-null float64
# x3     20 non-null float64
# x4     20 non-null float64
# x5     20 non-null float64
# x6     20 non-null int64
# x7     20 non-null float64
# x8     20 non-null float64
# x9     20 non-null float64
# x10    20 non-null float64
# x11    20 non-null float64
# x12    20 non-null float64
# x13    20 non-null int64
# y      20 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 2.3 KB

# %%
data1.head()
# Out:
#         x1      x2      x3        x4       x5       x6      x7       x8  \
# 0  3831732  181.54  448.19   7571.00  6212.70  6370241  525.71   985.31
# 1  3913824  214.63  549.97   9038.16  7601.73  6467115  618.25  1259.20
# 2  3928907  239.56  686.44   9905.31  8092.82  6560508  638.94  1468.06
# 3  4282130  261.58  802.59  10444.60  8767.98  6664862  656.58  1678.12
# 4  4453911  283.14  904.57  11255.70  9422.33  6741400  758.83  1893.52
#
#       x9     x10    x11    x12   x13       y
# 0  60.62   65.66  120.0  1.029  5321   64.87
# 1  73.46   95.46  113.5  1.051  6529   99.75
# 2  81.16   81.16  108.2  1.064  7008   88.11
# 3  85.72   91.70  102.2  1.092  7694  106.07
# 4  88.88  114.61   97.7  1.200  8027  137.32

# %% [markdown]
# 13-1-1 描述性分析

# %%
r = pd.DataFrame(data1.describe()).T
# 保留两位小数
np.round(r, 2)

# %% [markdown]
# 13-1-2 相关分析

# %%
# 计算相关系数矩阵
np.round(data1.corr(method = 'pearson'), 2)
# Out:
#        x1    x2    x3    x4    x5    x6    x7    x8    x9   x10   x11   x12  \
# x1   1.00  0.95  0.95  0.97  0.97  0.99  0.95  0.97  0.98  0.98 -0.29  0.94
# x2   0.95  1.00  1.00  0.99  0.99  0.92  0.99  0.99  0.98  0.98 -0.13  0.89
# x3   0.95  1.00  1.00  0.99  0.99  0.92  1.00  0.99  0.98  0.99 -0.15  0.89
# x4   0.97  0.99  0.99  1.00  1.00  0.95  0.99  1.00  0.99  1.00 -0.19  0.91
# x5   0.97  0.99  0.99  1.00  1.00  0.95  0.99  1.00  0.99  1.00 -0.18  0.90
# x6   0.99  0.92  0.92  0.95  0.95  1.00  0.93  0.95  0.97  0.96 -0.34  0.95
# x7   0.95  0.99  1.00  0.99  0.99  0.93  1.00  0.99  0.98  0.99 -0.15  0.89
# x8   0.97  0.99  0.99  1.00  1.00  0.95  0.99  1.00  0.99  1.00 -0.15  0.90
# x9   0.98  0.98  0.98  0.99  0.99  0.97  0.98  0.99  1.00  0.99 -0.23  0.91
# x10  0.98  0.98  0.99  1.00  1.00  0.96  0.99  1.00  0.99  1.00 -0.17  0.90
# x11 -0.29 -0.13 -0.15 -0.19 -0.18 -0.34 -0.15 -0.15 -0.23 -0.17  1.00 -0.43
# x12  0.94  0.89  0.89  0.91  0.90  0.95  0.89  0.90  0.91  0.90 -0.43  1.00
# x13  0.96  1.00  1.00  1.00  0.99  0.94  1.00  1.00  0.99  0.99 -0.16  0.90
# y    0.94  0.98  0.99  0.99  0.99  0.91  0.99  0.99  0.98  0.99 -0.12  0.87
#
#       x13     y
# x1   0.96  0.94
# x2   1.00  0.98
# x3   1.00  0.99
# x4   1.00  0.99
# x5   0.99  0.99
# x6   0.94  0.91
# x7   1.00  0.99
# x8   1.00  0.99
# x9   0.99  0.98
# x10  0.99  0.99
# x11 -0.16 -0.12
# x12  0.90  0.87
# x13  1.00  0.99
# y    0.99  1.00

# %% [markdown]
# 13-2 模型构建

# %% [markdown]
# 13-2-1 Lasso变量选择

# %%
from sklearn.linear_model import Lasso

model = Lasso(tol = 1)
model.fit(data1.iloc[:, 0:13], data1['y'])
model.coef_    # 各个特征的系数
# Out:
# array([ 4.07005680e-04,  2.02781609e-01,  8.56717095e-03, -3.51645774e-03,
#         1.83548359e-04, -1.91284850e-04,  1.17122737e-01, -6.50762881e-03,
#        -4.30958088e-01,  5.18365942e-02,  1.06661718e+01, -7.06390827e+01,
#         3.75255292e-03])

# %% [markdown]
# 13-2-2 地方财政收入灰色预测

# %%
def GM11(x0):
    # 1-AGO序列, 累计求和
    x1 = np.cumsum(x0)
    # 紧邻均值（MEAN）生成序列
    z1 = (x1[:-1] + x1[1:]) / 2.0
    z1 = z1.reshape(len(z1), 1)
    B = np.append(-z1, np.ones_like(z1), axis = 1)
    Yn = x0[1:].reshape((len(x0) - 1, 1))
    # 矩阵计算，计算参数
    [[a], [b]] = np.dot(np.dot(np.linalg.inv(np.dot(B.T, B)), B.T), Yn)
    # 还原值

    f = lambda k: (x0[0] - b / a) * np.exp(-a * (k - 1)) - (x0[0] - b / a) * np.exp(- a * (k - 2))

    delta = np.abs(x0 - np.array([f(i) for i in range(1, len(x0) + 1)]))
    C = delta.std() / x0.std()
    P = 1.0 * (np.abs(delta - delta.mean()) < 0.6745 * x0.std()).sum() / len(x0)
    
    # 灰度预测函数、a、b、首项、方差比、小残差概率
    return f, a, b, x0[0], C, P

# %%
outputfile_GM11 = path + '/tmp/data1_GM11.xls'    # 灰色预测后保存路径
data1.index = range(1994, 2014)

data1.loc[2014] = None
data1.loc[2015] = None
feature_lst = ['x1', 'x2', 'x3', 'x4', 'x5', 'x7']
for i in feature_lst:
    f = GM11(data1[i][list(range(1994, 2014))].as_matrix())[0]
    # 2014年预测结果
    data1[i][2014] = f(len(data1) - 1)
    # 2015年预测结果
    data1[i][2015] = f(len(data1))
    # 保留两位小数
    data1[i] = data1[i].round(2)

print(data1[feature_lst + ['y']])
data1[feature_lst + ['y']].to_excel(outputfile_GM11)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#               x1       x2       x3        x4        x5       x7        y
# 1994  3831732.00   181.54   448.19   7571.00   6212.70   525.71    64.87
# 1995  3913824.00   214.63   549.97   9038.16   7601.73   618.25    99.75
# 1996  3928907.00   239.56   686.44   9905.31   8092.82   638.94    88.11
# 1997  4282130.00   261.58   802.59  10444.60   8767.98   656.58   106.07
# 1998  4453911.00   283.14   904.57  11255.70   9422.33   758.83   137.32
# 1999  4548852.00   308.58  1000.69  12018.52   9751.44   878.26   188.14
# 2000  4962579.00   348.09  1121.13  13966.53  11349.47   923.67   219.91
# 2001  5029338.00   387.81  1248.29  14694.00  11467.35   978.21   271.91
# 2002  5070216.00   453.49  1370.68  13380.47  10671.78  1009.24   269.10
# 2003  5210706.00   533.55  1494.27  15002.59  11570.58  1175.17   300.55
# 2004  5407087.00   598.33  1677.77  16884.16  13120.83  1348.93   338.45
# 2005  5744550.00   665.32  1905.84  18287.24  14468.24  1519.16   408.86
# 2006  5994973.00   738.97  2199.14  19850.66  15444.93  1696.38   476.72
# 2007  6236312.00   877.07  2624.24  22469.22  18951.32  1863.34   838.99
# 2008  6529045.00  1005.37  3187.39  25316.72  20835.95  2105.54   843.14
# 2009  6791495.00  1118.03  3615.77  27609.59  22820.89  2659.85  1107.67
# 2010  7110695.00  1304.48  4476.38  30658.49  25011.61  3263.57  1399.16
# 2011  7431755.00  1700.87  5243.03  34438.08  28209.74  3412.21  1535.14
# 2012  7512997.00  1969.51  5977.27  38053.52  30490.44  3758.39  1579.68
# 2013  7599295.00  2110.78  6882.85  42049.14  33156.83  4454.55  2088.14
# 2014  8142148.24  2239.29  7042.31  43611.84  35046.63  4600.40      NaN
# 2015  8460489.28  2581.14  8166.92  47792.22  38384.22  5214.78      NaN

# %% [markdown]
# 13-2-3 地方财政收入神经网络预测模型

# %%
outputfile_LM = path + '/data/revenue.xls'
modelfile = path + '/tmp/net-revenue.model'

data_LM = data1[feature_lst + ['y']]
data_train = data_LM.loc[range(1994, 2014)].copy()    # 取2014年前的数据
data_mean = data_train.mean()
data_std = data_train.std()
# 数据标准化
data_train = (data_train - data_mean) / data_std
    
# 特征数据
x_train = data_train[feature_lst].as_matrix()
# 标签数据
y_train = data_train['y'].as_matrix()
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if sys.path[0] == '':
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
from keras.models import Sequential
from keras.layers.core import Activation, Dense

model = Sequential()
model.add(Dense(input_dim = 6, units = 12))
model.add(Activation('relu'))
model.add(Dense(input_dim = 12, units = 1))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.fit(x_train, y_train, epochs = 10000, batch_size = 16)
model.save_weights(modelfile)

# 预测，并且还原结果
x = (
    (data_LM[feature_lst] - data_mean[feature_lst]) /
     data_std[feature_lst]
).as_matrix()
data_LM['y_pred'] = model.predict(x) * data_std['y'] + data_mean['y']
data_LM['y_pred'] = data_LM['y_pred'].round(2)
data_LM.to_excel(outputfile_LM)
# Out:
# D:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Epoch 1/10000
# 20/20 [==============================] - 1s 28ms/step - loss: 5.0096
# Epoch 2/10000
# 20/20 [==============================] - 0s 725us/step - loss: 4.8350
# Epoch 3/10000
# 20/20 [==============================] - 0s 1ms/step - loss: 4.6805
# Epoch 4/10000
# 20/20 [==============================] - 0s 775us/step - loss: 4.5263
# Epoch 5/10000
# 20/20 [==============================] - 0s 600us/step - loss: 4.3851
# Epoch 6/10000
# 20/20 [==============================] - 0s 375us/step - loss: 4.2310
# Epoch 7/10000
# 20/20 [==============================] - 0s 875us/step - loss: 4.0947
# Epoch 8/10000
# 20/20 [==============================] - 0s 450us/step - loss: 3.9658
# Epoch 9/10000
# 20/20 [==============================] - 0s 350us/step - loss: 3.8297
# Epoch 10/10000
# 20/20 [==============================] - 0s 475us/step - loss: 3.7053
# Epoch 11/10000
# 20/20 [==============================] - 0s 450us/step - loss: 3.5852
# Epoch 12/10000
# 20/20 [==============================] - 0s 525us/step - loss: 3.4666
# Epoch 13/10000
# 20/20 [==============================] - 0s 375us/step - loss: 3.3477
# Epoch 14/10000
# 20/20 [==============================] - 0s 500us/step - loss: 3.2406
# Epoch 15/10000
# 20/20 [==============================] - 0s 450us/step - loss: 3.1227
# Epoch 16/10000
# 20/20 [==============================] - 0s 401us/step - loss: 3.0243
# Epoch 17/10000
# 20/20 [==============================] - 0s 400us/step - loss: 2.9194
# Epoch 18/10000
# 20/20 [==============================] - 0s 425us/step - loss: 2.8209
# Epoch 19/10000
# 20/20 [==============================] - 0s 525us/step - loss: 2.7275
# Epoch 20/10000
# 20/20 [==============================] - 0s 450us/step - loss: 2.6377
# Epoch 21/10000
# 20/20 [==============================] - 0s 400us/step - loss: 2.5412
# Epoch 22/10000
# 20/20 [==============================] - 0s 400us/step - loss: 2.4650
# Epoch 23/10000
# 20/20 [==============================] - 0s 400us/step - loss: 2.3805
# Epoch 24/10000
# 20/20 [==============================] - 0s 400us/step - loss: 2.3020
# Epoch 25/10000
# 20/20 [==============================] - 0s 400us/step - loss: 2.2257
# Epoch 26/10000
# 20/20 [==============================] - 0s 550us/step - loss: 2.1558
# Epoch 27/10000
# 20/20 [==============================] - 0s 400us/step - loss: 2.0861
# Epoch 28/10000
# 20/20 [==============================] - 0s 425us/step - loss: 2.0173
# Epoch 29/10000
# 20/20 [==============================] - 0s 400us/step - loss: 1.9560
# Epoch 30/10000
# 20/20 [==============================] - 0s 425us/step - loss: 1.8916
# Epoch 31/10000
# 20/20 [==============================] - 0s 400us/step - loss: 1.8359
# Epoch 32/10000
# 20/20 [==============================] - 0s 400us/step - loss: 1.7738
# Epoch 33/10000
# 20/20 [==============================] - 0s 350us/step - loss: 1.7164
# Epoch 34/10000
# 20/20 [==============================] - 0s 525us/step - loss: 1.6631
# Epoch 35/10000
# 20/20 [==============================] - 0s 425us/step - loss: 1.6043
# Epoch 36/10000
# 20/20 [==============================] - 0s 450us/step - loss: 1.5510
# Epoch 37/10000
# 20/20 [==============================] - 0s 525us/step - loss: 1.4968
# Epoch 38/10000
# 20/20 [==============================] - 0s 475us/step - loss: 1.4476
# Epoch 39/10000
# 20/20 [==============================] - 0s 475us/step - loss: 1.3939
# Epoch 40/10000
# 20/20 [==============================] - 0s 375us/step - loss: 1.3457
# Epoch 41/10000
# 20/20 [==============================] - 0s 550us/step - loss: 1.2974
# Epoch 42/10000
# 20/20 [==============================] - 0s 475us/step - loss: 1.2522
# Epoch 43/10000
# 20/20 [==============================] - 0s 475us/step - loss: 1.2073
# Epoch 44/10000
# 20/20 [==============================] - 0s 425us/step - loss: 1.1612
# Epoch 45/10000
# 20/20 [==============================] - 0s 477us/step - loss: 1.1222
# Epoch 46/10000
# 20/20 [==============================] - 0s 450us/step - loss: 1.0837
# Epoch 47/10000
# 20/20 [==============================] - 0s 400us/step - loss: 1.0471
# Epoch 48/10000
# 20/20 [==============================] - 0s 500us/step - loss: 1.0076
# Epoch 49/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.9794
# Epoch 50/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.9435
# Epoch 51/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.9133
# Epoch 52/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.8831
# Epoch 53/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.8557
# Epoch 54/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.8251
# Epoch 55/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.8001
# Epoch 56/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.7713
# Epoch 57/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.7474
# Epoch 58/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.7215
# Epoch 59/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.6977
# Epoch 60/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.6715
# Epoch 61/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.6511
# Epoch 62/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.6288
# Epoch 63/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.6056
# Epoch 64/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.5869
# Epoch 65/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.5669
# Epoch 66/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.5497
# Epoch 67/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.5325
# Epoch 68/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.5155
# Epoch 69/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.5003
# Epoch 70/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.4849
# Epoch 71/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.4691
# Epoch 72/10000
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4538
# Epoch 73/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.4412
# Epoch 74/10000
# 20/20 [==============================] - 0s 600us/step - loss: 0.4250
# Epoch 75/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.4129
# Epoch 76/10000
# 20/20 [==============================] - 0s 401us/step - loss: 0.3990
# Epoch 77/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.3856
# Epoch 78/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.3741
# Epoch 79/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.3612
# Epoch 80/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.3496
# Epoch 81/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.3382
# Epoch 82/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.3267
# Epoch 83/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.3160
# Epoch 84/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.3047
# Epoch 85/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.2938
# Epoch 86/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.2839
# Epoch 87/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.2735
# Epoch 88/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.2648
# Epoch 89/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.2558
# Epoch 90/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.2460
# Epoch 91/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.2389
# Epoch 92/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.2310
# Epoch 93/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.2232
# Epoch 94/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.2163
# Epoch 95/10000
# 20/20 [==============================] - 0s 1ms/step - loss: 0.2091
# Epoch 96/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.2021
# Epoch 97/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.1963
# Epoch 98/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.1901
# Epoch 99/10000
# 20/20 [==============================] - 0s 498us/step - loss: 0.1840
# Epoch 100/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.1788
# Epoch 101/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.1731
# Epoch 102/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.1681
# Epoch 103/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.1631
# Epoch 104/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.1584
# Epoch 105/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.1530
# Epoch 106/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.1484
# Epoch 107/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.1433
# Epoch 108/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.1390
# Epoch 109/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.1341
# Epoch 110/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.1298
# Epoch 111/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.1253
# Epoch 112/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.1209
# Epoch 113/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.1174
# Epoch 114/10000
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1137
# Epoch 115/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.1097
# Epoch 116/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.1060
# Epoch 117/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.1026
# Epoch 118/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0995
# Epoch 119/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0964
# Epoch 120/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0935
# Epoch 121/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0906
# Epoch 122/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0879
# Epoch 123/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0855
# Epoch 124/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0828
# Epoch 125/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0806
# Epoch 126/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0782
# Epoch 127/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0759
# Epoch 128/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0737
# Epoch 129/10000
# 16/20 [=======================>......] - ETA: 0s - loss: 0.0778
# D:\Anaconda3\lib\site-packages\keras\callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.398021). Check your callbacks.
#   % delta_t_median)
# D:\Anaconda3\lib\site-packages\keras\callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.199011). Check your callbacks.
#   % delta_t_median)
# 20/20 [==============================] - 0s 500us/step - loss: 0.0717
# Epoch 130/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0697
# Epoch 131/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0678
# Epoch 132/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0659
# Epoch 133/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0642
# Epoch 134/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0626
# Epoch 135/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0610
# Epoch 136/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0595
# Epoch 137/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0579
# Epoch 138/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0565
# Epoch 139/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0552
# Epoch 140/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0539
# Epoch 141/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0524
# Epoch 142/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0513
# Epoch 143/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0501
# Epoch 144/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0489
# Epoch 145/10000
# 20/20 [==============================] - 0s 499us/step - loss: 0.0476
# Epoch 146/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0466
# Epoch 147/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0455
# Epoch 148/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0444
# Epoch 149/10000
# 20/20 [==============================] - 0s 600us/step - loss: 0.0434
# Epoch 150/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0423
# Epoch 151/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.0412
# Epoch 152/10000
# 20/20 [==============================] - 0s 600us/step - loss: 0.0402
# Epoch 153/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0393
# Epoch 154/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.0383
# Epoch 155/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0373
# Epoch 156/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0367
# Epoch 157/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0358
# Epoch 158/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0352
# Epoch 159/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0344
# Epoch 160/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0337
# Epoch 161/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0329
# Epoch 162/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0323
# Epoch 163/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0317
# Epoch 164/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0310
# Epoch 165/10000
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0303
# Epoch 166/10000
# 20/20 [==============================] - 0s 475us/step - loss: 0.0298
# Epoch 167/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0292
# Epoch 168/10000
# 20/20 [==============================] - 0s 475us/step - loss: 0.0286
# Epoch 169/10000
# 20/20 [==============================] - 0s 475us/step - loss: 0.0281
# Epoch 170/10000
# 20/20 [==============================] - 0s 425us/step - loss: 0.0276
# Epoch 171/10000
# 20/20 [==============================] - 0s 475us/step - loss: 0.0270
# Epoch 172/10000
# 20/20 [==============================] - 0s 425us/step - loss: 0.0266
# Epoch 173/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0262
# Epoch 174/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0258
# Epoch 175/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0255
# Epoch 176/10000
# 20/20 [==============================] - 0s 375us/step - loss: 0.0251
# Epoch 177/10000
# 20/20 [==============================] - 0s 425us/step - loss: 0.0248
# Epoch 178/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0245
# Epoch 179/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0243
# Epoch 180/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0240
# Epoch 181/10000
# 20/20 [==============================] - 0s 475us/step - loss: 0.0237
# Epoch 182/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0236
# Epoch 183/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0233
# Epoch 184/10000
# 20/20 [==============================] - 0s 425us/step - loss: 0.0231
# Epoch 185/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0230
# Epoch 186/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0228
# Epoch 187/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0227
# Epoch 188/10000
# 20/20 [==============================] - 0s 425us/step - loss: 0.0225
# Epoch 189/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0223
# Epoch 190/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0222
# Epoch 191/10000
# 20/20 [==============================] - 0s 475us/step - loss: 0.0220
# Epoch 192/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0219
# Epoch 193/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0218
# Epoch 194/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0216
# Epoch 195/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0216
# Epoch 196/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0214
# Epoch 197/10000
# 20/20 [==============================] - 0s 425us/step - loss: 0.0212
# Epoch 198/10000
# 20/20 [==============================] - 0s 475us/step - loss: 0.0211
# Epoch 199/10000
# 20/20 [==============================] - 0s 475us/step - loss: 0.0210
# Epoch 200/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0208
# Epoch 201/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0207
# Epoch 202/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0206
# Epoch 203/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0205
# Epoch 204/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0204
# Epoch 205/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0204
# Epoch 206/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0203
# Epoch 207/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0202
# Epoch 208/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0201
# Epoch 209/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0201
# Epoch 210/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0200
# Epoch 211/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0200
# Epoch 212/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0200
# Epoch 213/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0200
# Epoch 214/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0199
# Epoch 215/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0198
# Epoch 216/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0198
# Epoch 217/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0197
# Epoch 218/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0197
# Epoch 219/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0197
# Epoch 220/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0196
# Epoch 221/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0195
# Epoch 222/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.0196
# Epoch 223/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0195
# Epoch 224/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0195
# Epoch 225/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0196
# Epoch 226/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0195
# Epoch 227/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0195
# Epoch 228/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0195
# Epoch 229/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0195
# Epoch 230/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0195
# Epoch 231/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0195
# Epoch 232/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0194
# Epoch 233/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0194
# Epoch 234/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0194
# Epoch 235/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0193
# Epoch 236/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0194
# Epoch 237/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0192
# Epoch 238/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0192
# Epoch 239/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0192
# Epoch 240/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0192
# Epoch 241/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0192
# Epoch 242/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0191
# Epoch 243/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0191
# Epoch 244/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0191
# Epoch 245/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0191
# Epoch 246/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0191
# Epoch 247/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0191
# Epoch 248/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0191
# Epoch 249/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0191
# Epoch 250/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0191
# Epoch 251/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0191
# Epoch 252/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0191
# Epoch 253/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0190
# Epoch 254/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0190
# Epoch 255/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0190
# Epoch 256/10000
# 20/20 [==============================] - 0s 600us/step - loss: 0.0190
# Epoch 257/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0189
# Epoch 258/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0188
# Epoch 259/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0188
# Epoch 260/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0188
# Epoch 261/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0187
# Epoch 262/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0187
# Epoch 263/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 264/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0188
# Epoch 265/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0187
# Epoch 266/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0187
# Epoch 267/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 268/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0186
# Epoch 269/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 270/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0186
# Epoch 271/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0186
# Epoch 272/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 273/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 274/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0186
# Epoch 275/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 276/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0186
# Epoch 277/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 278/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 279/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0186
# Epoch 280/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0186
# Epoch 281/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 282/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0185
# Epoch 283/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0185
# Epoch 284/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0185
# Epoch 285/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0184
# Epoch 286/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0184
# Epoch 287/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0185
# Epoch 288/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0184
# Epoch 289/10000
# 20/20 [==============================] - 0s 700us/step - loss: 0.0184
# Epoch 290/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0183
# Epoch 291/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 292/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0185
# Epoch 293/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0185
# Epoch 294/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0186
# Epoch 295/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0186
# Epoch 296/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0185
# Epoch 297/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0185
# Epoch 298/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 299/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 300/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0186
# Epoch 301/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0186
# Epoch 302/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0186
# Epoch 303/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0185
# Epoch 304/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0185
# Epoch 305/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0184
# Epoch 306/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0184
# Epoch 307/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0183
# Epoch 308/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0183
# Epoch 309/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0183
# Epoch 310/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0182
# Epoch 311/10000
# 20/20 [==============================] - 0s 600us/step - loss: 0.0182
# Epoch 312/10000
# 20/20 [==============================] - 0s 600us/step - loss: 0.0182
# Epoch 313/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0182
# Epoch 314/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0182
# Epoch 315/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0182
# Epoch 316/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0181
# Epoch 317/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0181
# Epoch 318/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0181
# Epoch 319/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0181
# Epoch 320/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0181
# Epoch 321/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0180
# Epoch 322/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0182
# Epoch 323/10000
# 20/20 [==============================] - 0s 550us/step - loss: 0.0181
# Epoch 324/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0180
# Epoch 325/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0180
# Epoch 326/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0180
# Epoch 327/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0180
# Epoch 328/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0180
# Epoch 329/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0180
# Epoch 330/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0180
# Epoch 331/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0180
# Epoch 332/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0180
# Epoch 333/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0180
# Epoch 334/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0180
# Epoch 335/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.0180
# Epoch 336/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.0179
# Epoch 337/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.0179
# Epoch 338/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.0179
# Epoch 339/10000
# 20/20 [==============================] - 0s 300us/step - loss: 0.0179
# Epoch 340/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.0179
# Epoch 341/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.0180
# Epoch 342/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.0181
# Epoch 343/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.0181
# Epoch 344/10000
# 20/20 [==============================] - 0s 350us/step - loss: 0.0181
# Epoch 345/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0181
# Epoch 346/10000
# 20/20 [==============================] - 0s 600us/step - loss: 0.0181
# Epoch 347/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0180
# Epoch 348/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0180
# Epoch 349/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0180
# Epoch 350/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0180
# Epoch 351/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0181
# Epoch 352/10000
# 20/20 [==============================] - 0s 600us/step - loss: 0.0182
# Epoch 353/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0181
# Epoch 354/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0181
# Epoch 355/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0180
# Epoch 356/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0179
# Epoch 357/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0178
# Epoch 358/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0177
# Epoch 359/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0179
# Epoch 360/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0177
# Epoch 361/10000
# 20/20 [==============================] - ETA: 0s - loss: 0.016 - 0s 800us/step - loss: 0.0176
# Epoch 362/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0177
# Epoch 363/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0176
# Epoch 364/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0176
# Epoch 365/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0177
# Epoch 366/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0177
# Epoch 367/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0177
# Epoch 368/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0178
# Epoch 369/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0178
# Epoch 370/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0178
# Epoch 371/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0178
# Epoch 372/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0179
# Epoch 373/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0179
# Epoch 374/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0178
# Epoch 375/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0178
# Epoch 376/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0177
# Epoch 377/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0175
# Epoch 378/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0175
# Epoch 379/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0176
# Epoch 380/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0175
# Epoch 381/10000
# 20/20 [==============================] - 0s 400us/step - loss: 0.0175
# Epoch 382/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0175
# Epoch 383/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0175
# Epoch 384/10000
# 20/20 [==============================] - 0s 450us/step - loss: 0.0175
# Epoch 385/10000
# 20/20 [==============================] - 0s 500us/step - loss: 0.0175

# %%
# 画出预测结果图
data_LM[['y', 'y_pred']].plot(subplots = True, style = ['b-o', 'r-*'])
plt.show()

# %% [markdown]
# 13-3 增值税预测

# %% [markdown]
# 13-3-1 Lasso变量选择

# %%
inputfile = path + '/data/data2.csv'
data2 = pd.read_csv(inputfile)
data2.info()

# %%
data2

# %%
model = Lasso(tol = 1)
model.fit(data2.iloc[:, 0:6], data2['y'])
model.coef_    # 各个特征的系数

# %% [markdown]
# 13-3-2 增值税灰色预测

# %%
outputfile_GM11 = path + '/tmp/data2_GM11.xls'    # 灰色预测后保存路径
data2.index = range(1999, 2014)

data2.loc[2014] = None
data2.loc[2015] = None
feature_lst = ['x1', 'x3', 'x5']
for i in feature_lst:
    f = GM11(data2[i][list(range(1999, 2014))].as_matrix())[0]
    # 2014年预测结果
    data2[i][2014] = f(len(data2) - 1)
    # 2015年预测结果
    data2[i][2015] = f(len(data2))
    # 保留两位小数
    data2[i] = data2[i].round(6)

print(data2[feature_lst + ['y']])
data2[feature_lst + ['y']].to_excel(outputfile_GM11)

# %% [markdown]
# 13-3-3 增值税神经网络预测模型

# %%
outputfile_LM = path + '/data/VAT.xls'
modelfile = path + '/tmp/net-VAT.model'

data_LM = data2[feature_lst + ['y']]
data_train = data_LM.loc[range(1999, 2014)].copy()    # 取2014年前的数据
data_mean = data_train.mean()
data_std = data_train.std()
# 数据标准化
data_train = (data_train - data_mean) / data_std
    
# 特征数据
x_train = data_train[feature_lst].as_matrix()
# 标签数据
y_train = data_train['y'].as_matrix()

# %%
model = Sequential()
model.add(Dense(input_dim = 3, units = 6))
model.add(Activation('relu'))
model.add(Dense(input_dim = 6, units = 1))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.fit(x_train, y_train, epochs = 10000, batch_size = 16)
model.save_weights(modelfile)

# 预测，并且还原结果
x = (
    (data_LM[feature_lst] - data_mean[feature_lst]) /
     data_std[feature_lst]
).as_matrix()
data_LM['y_pred'] = model.predict(x) * data_std['y'] + data_mean['y']
data_LM['y_pred'] = data_LM['y_pred'].round(6)
data_LM.to_excel(outputfile_LM)

# %%
# 画出预测结果图
data_LM[['y', 'y_pred']].plot(subplots = True, style = ['b-o', 'r-*'])
plt.show()

# %% [markdown]
# 13-4 营业税预测模型

# %% [markdown]
# 13-4-1 Lasso变量选择

# %%
inputfile = path + '/data/data3.csv'
data3 = pd.read_csv(inputfile)
data3.info()

# %%
data3

# %%
model = Lasso(tol = 1)
model.fit(data3.iloc[:, 0:10], data3['y'])
model.coef_    # 各个特征的系数

# %% [markdown]
# 13-4-2 灰色预测

# %%
outputfile_GM11 = path + '/tmp/data3_GM11.xls'    # 灰色预测后保存路径
data3.index = range(1999, 2014)

data3.loc[2014] = None
data3.loc[2015] = None
feature_lst = ['x3', 'x4', 'x6', 'x8']
for i in feature_lst:
    f = GM11(data3[i][list(range(1999, 2014))].as_matrix())[0]
    # 2014年预测结果
    data3[i][2014] = f(len(data3) - 1)
    # 2015年预测结果
    data3[i][2015] = f(len(data3))
    # 取整
    data3[i] = data3[i].round()

print(data3[feature_lst + ['y']])
data3[feature_lst + ['y']].to_excel(outputfile_GM11)

# %% [markdown]
# 13-4-3 神经网络预测模型

# %%
# 神经网络预测模型
outputfile_LM = path + '/data/sales_tax.xls'
modelfile = path + '/tmp/net-sales_tax.model'

data_LM = data3[feature_lst + ['y']]
data_train = data_LM.loc[range(1999, 2014)].copy()    # 取2014年前的数据
data_mean = data_train.mean()
data_std = data_train.std()
# 数据标准化
data_train = (data_train - data_mean) / data_std
    
# 特征数据
x_train = data_train[feature_lst].as_matrix()
# 标签数据
y_train = data_train['y'].as_matrix()

# %%
model = Sequential()
model.add(Dense(input_dim = 4, units = 8))
model.add(Activation('relu'))
model.add(Dense(input_dim = 8, units = 1))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.fit(x_train, y_train, epochs = 10000, batch_size = 16)
model.save_weights(modelfile)

# 预测，并且还原结果
x = (
    (data_LM[feature_lst] - data_mean[feature_lst]) /
     data_std[feature_lst]
).as_matrix()
data_LM['y_pred'] = model.predict(x) * data_std['y'] + data_mean['y']
data_LM['y_pred'] = data_LM['y_pred'].round(2)
data_LM.to_excel(outputfile_LM)

# %%
# 画出预测结果图
data_LM[['y', 'y_pred']].plot(subplots = True, style = ['b-o', 'r-*'])
plt.show()

# %% [markdown]
# 13-5 企业所得税预测模型

# %% [markdown]
# 13-5-1 Lasso变量选择

# %%
inputfile = path + '/data/data4.csv'
data4 = pd.read_csv(inputfile)
data4.info()

# %%
data4

# %%
model = Lasso(tol = 1)
model.fit(data4.iloc[:, 0:10], data4['y'])
model.coef_    # 各个特征的系数

# %% [markdown]
# 13-5-2 灰色预测

# %%
outputfile_GM11 = path + '/tmp/data4_GM11.xls'    # 灰色预测后保存路径
data4.index = range(2002, 2014)

data4.loc[2014] = None
data4.loc[2015] = None
feature_lst = ['x1', 'x2', 'x3', 'x4', 'x6', 'x7', 'x9', 'x10']
for i in feature_lst:
    f = GM11(data4[i][list(range(2002, 2014))].as_matrix())[0]
    # 2014年预测结果
    data4[i][2014] = f(len(data4) - 1)
    # 2015年预测结果
    data4[i][2015] = f(len(data4))
    data4[i] = data4[i].round(2)

print(data4[feature_lst + ['y']])
data4[feature_lst + ['y']].to_excel(outputfile_GM11)

# %% [markdown]
# 13-5-3 神经网络预测模型

# %%
outputfile_LM = path + '/data/enterprise_income.xls'
modelfile = path + '/tmp/net-enterprise_income.model'

data_LM = data4[feature_lst + ['y']]
data_train = data_LM.loc[range(2002, 2014)].copy()    # 取2014年前的数据
data_mean = data_train.mean()
data_std = data_train.std()
# 数据标准化
data_train = (data_train - data_mean) / data_std
    
# 特征数据
x_train = data_train[feature_lst].as_matrix()
# 标签数据
y_train = data_train['y'].as_matrix()

# %%
model = Sequential()
model.add(Dense(input_dim = 8, units = 6))
model.add(Activation('relu'))
model.add(Dense(input_dim = 6, units = 1))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.fit(x_train, y_train, epochs = 10000, batch_size = 16)
model.save_weights(modelfile)

# 预测，并且还原结果
x = (
    (data_LM[feature_lst] - data_mean[feature_lst]) /
     data_std[feature_lst]
).as_matrix()
data_LM['y_pred'] = model.predict(x) * data_std['y'] + data_mean['y']
data_LM['y_pred'] = data_LM['y_pred'].round()
data_LM.to_excel(outputfile_LM)

# %%
# 画出预测结果图
data_LM[['y', 'y_pred']].plot(subplots = True, style = ['b-o', 'r-*'])
plt.show()

# %% [markdown]
# 13-6 个人所得税预测模型

# %% [markdown]
# 13-6-1 Lasso变量选择

# %%
inputfile = path + '/data/data5.csv'
data5 = pd.read_csv(inputfile)
data5.info()

# %%
data5

# %%
model = Lasso(tol = 1)
model.fit(data5.iloc[:, 0:7], data5['y'])
model.coef_    # 各个特征的系数

# %% [markdown]
# 13-6-2 灰色预测

# %%
outputfile_GM11 = path + '/tmp/data5_GM11.xls'    # 灰色预测后保存路径
data5.index = range(2000, 2014)

data5.loc[2014] = None
data5.loc[2015] = None
feature_lst = ['x1', 'x4', 'x5', 'x7']
for i in feature_lst:
    f = GM11(data5[i][list(range(2000, 2014))].as_matrix())[0]
    # 2014年预测结果
    data5[i][2014] = f(len(data5) - 1)
    # 2015年预测结果
    data5[i][2015] = f(len(data5))
    data5[i] = data5[i].round()

print(data5[feature_lst + ['y']])
data5[feature_lst + ['y']].to_excel(outputfile_GM11)

# %% [markdown]
# 13-6-3 神经网络预测模型

# %%
outputfile_LM = path + '/data/personal_income.xls'
modelfile = path + '/tmp/net-personal_income.model'

data_LM = data5[feature_lst + ['y']]
data_train = data_LM.loc[range(2000, 2014)].copy()    # 取2014年前的数据
data_mean = data_train.mean()
data_std = data_train.std()
# 数据标准化
data_train = (data_train - data_mean) / data_std
    
# 特征数据
x_train = data_train[feature_lst].as_matrix()
# 标签数据
y_train = data_train['y'].as_matrix()

# %%
model = Sequential()
model.add(Dense(input_dim = 4, units = 8))
model.add(Activation('relu'))
model.add(Dense(input_dim = 8, units = 1))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.fit(x_train, y_train, epochs = 15000, batch_size = 16)
model.save_weights(modelfile)

# 预测，并且还原结果
x = (
    (data_LM[feature_lst] - data_mean[feature_lst]) /
     data_std[feature_lst]
).as_matrix()
data_LM['y_pred'] = model.predict(x) * data_std['y'] + data_mean['y']
data_LM['y_pred'] = data_LM['y_pred'].round()
data_LM.to_excel(outputfile_LM)

# %%
# 画出预测结果图
data_LM[['y', 'y_pred']].plot(subplots = True, style = ['b-o', 'r-*'])
plt.show()

# %% [markdown]
# 13-7 政府性基金收入灰色预测

# %%
x0 = np.array([3152063, 2213050, 4050122,
               5265142, 5556619, 4772843, 9463330])
f, a, b, x00, C, P = GM11(x0)
print(a, b, x00, C, P)
print('\n')
print(u'2014年、2015年的预测结果分别为：\n%0.2f万元和%0.2f万元' % (f(8), f(9)))
print(u'后验差比值为：%0.4f' % C)
data = pd.DataFrame(x0, columns = ['y'], index = range(2007, 2014))
data.loc[2014] = None
data.loc[2015] = None
data['y_pred'] = [f(i) for i in range(1, 10)]
data['y_pred'] = data['y_pred'].round(2)
data.index = pd.to_datetime(data.index, format = '%Y')

data.plot(style = ['b-o', 'r-*'], xticks = data.index)
plt.show()
